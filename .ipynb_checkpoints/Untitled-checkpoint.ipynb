# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
iplot([{"x": [1, 2, 3], "y": [3, 1, 6]}])
# Out:
# <div id="0a0d6b94-0dfa-4a64-b839-596274c9b4fb" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0a0d6b94-0dfa-4a64-b839-596274c9b4fb", [{"x": [1, 2, 3], "y": [3, 1, 6], "type": "scatter", "uid": "92e157d4-8a39-418b-80f5-872e701a3194"}], {}, {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly"})});</script><script type="text/javascript">window.addEventListener("resize", function(){window._Plotly.Plots.resize(document.getElementById("0a0d6b94-0dfa-4a64-b839-596274c9b4fb"));});</script>

# %%
import numpy as np #linear algebra library
import pandas as pd # data manipulation library

# %%
df_cmo = pd.read_csv('data/CMO_MSP_Mandi.csv')
df_cmo
# Out:
#                   commodity  year          Type  msprice  msp_filter
# 0            PADDY-UNHUSKED  2012  Kharif Crops   1250.0           1
# 1           RICE(PADDY-HUS)  2012  Kharif Crops   1280.0           1
# 2              Jowar_Hybrid  2012  Kharif Crops   1500.0           1
# 3             SORGUM(JAWAR)  2012  Kharif Crops   1520.0           1
# 4                     BAJRI  2012  Kharif Crops   1175.0           1
# 5                     MAIZE  2012  Kharif Crops   1175.0           1
# 6             Ragi_Maldandi  2012  Kharif Crops   1500.0           1
# 7          PIGEON PEA (TUR)  2012  Kharif Crops   3850.0           1
# 8          SPILT GERRN GRAM  2012  Kharif Crops   4400.0           1
# 9          SPLIT BLACK GRAM  2012  Kharif Crops   4300.0           1
# 10                   COTTON  2012  Kharif Crops   3600.0           1
# 11       Cotton_Long Staple  2012  Kharif Crops   3900.0           1
# 12           GR.NUT KERNELS  2012  Kharif Crops   3700.0           1
# ...

# %%
df_monthly_cmo = pd.read_csv('data/Monthly_data_cmo.csv',index_col=0, parse_dates = [[2,3]], infer_datetime_format = True) #columns Year and Month will be used for time series analysis.
df_monthly_cmo
# Out:
#                           APMC         Commodity  arrivals_in_qtl  min_price  \
# Year_Month
# 2015-04-01          Ahmednagar             Bajri               79       1406
# 2016-04-01          Ahmednagar             Bajri              106       1788
# 2015-04-01          Ahmednagar     Wheat(Husked)             1253       1572
# 2016-04-01          Ahmednagar     Wheat(Husked)              387       1750
# 2015-04-01          Ahmednagar     Sorgum(Jawar)             3825       1600
# 2016-04-01          Ahmednagar     Sorgum(Jawar)             2093       1695
# 2015-04-01          Ahmednagar             Maize               75       1345
# 2016-04-01          Ahmednagar             Maize              155       1367
# 2015-04-01          Ahmednagar              Gram             1794       3533
# 2016-04-01          Ahmednagar              Gram              630       4790
# 2015-04-01          Ahmednagar        Horse Gram                3       7150
# ...

# %% [markdown]
# ### Since data in df_monthly_cmo has a frequency of a month. Thus changing its sampling rate(Year_Month)

# %%
df_monthly_cmo = df_monthly_cmo.to_period(freq='M') #Converting to period index with monthly frequency.

# %%
df_monthly_cmo
# Out:
#                           APMC         Commodity  arrivals_in_qtl  min_price  \
# Year_Month
# 2015-04             Ahmednagar             Bajri               79       1406
# 2016-04             Ahmednagar             Bajri              106       1788
# 2015-04             Ahmednagar     Wheat(Husked)             1253       1572
# 2016-04             Ahmednagar     Wheat(Husked)              387       1750
# 2015-04             Ahmednagar     Sorgum(Jawar)             3825       1600
# 2016-04             Ahmednagar     Sorgum(Jawar)             2093       1695
# 2015-04             Ahmednagar             Maize               75       1345
# 2016-04             Ahmednagar             Maize              155       1367
# 2015-04             Ahmednagar              Gram             1794       3533
# 2016-04             Ahmednagar              Gram              630       4790
# 2015-04             Ahmednagar        Horse Gram                3       7150
# ...

# %% [markdown]
# # Analysing:df_cmo

# %%
df_cmo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155 entries, 0 to 154
# Data columns (total 5 columns):
# commodity     155 non-null object
# year          155 non-null int64
# Type          155 non-null object
# msprice       145 non-null float64
# msp_filter    155 non-null int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 6.1+ KB

# %% [markdown]
# #### Missing data Report:
# > msprice: contains 10 missing values <br>
# > commodity,year,Type,msp_filter: contains 0 missing values
